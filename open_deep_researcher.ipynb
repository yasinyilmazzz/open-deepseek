# %% [markdown]
# <a href="https://colab.research.google.com/github/yasinyilmazzz/open-deepseek/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)

# %%
import asyncio
import aiohttp
import json

# =======================
# Configuration Constants
# =======================
OPENROUTER_API_KEY = "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" # Replace with your OpenRouter API key
SERPAPI_API_KEY = "3b1470aadcd593e3e1764a46a836fe0b26520c869729b612f68c5a85a32d4059" # Replace with your SERPAPI API key
JINA_API_KEY = "jina_d91e4325afda4da3b440f73da28ef90cw2JkJRPg8CRddTipLIDrdXDGq1tJ" # Replace with your JINA API key

# Endpoints
OPENROUTER_URL = "https://openrouter.ai/api/v1/chat/completions"
SERPAPI_URL = "https://serpapi.com/search"
JINA_BASE_URL = "https://r.jina.ai/"

# Default LLM model (can be changed if desired)
DEFAULT_MODEL = "anthropic/claude-3.5-haiku"


# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(OPENROUTER_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using SERPAPI for the given query.
    Returns a list of result URLs.
    """
    params = {
        "q": query,
        "api_key": SERPAPI_API_KEY,
        "engine": "google"
    }
    try:
        async with session.get(SERPAPI_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "organic_results" in results:
                    links = [item.get("link") for item in results["organic_results"] if "link" in item]
                    return links
                else:
                    print("No organic results in SERPAPI response.")
                    return []
            else:
                text = await resp.text()
                print(f"SERPAPI error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing SERPAPI search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using Jina.
    The URL is appended to the Jina endpoint.
    """
    full_url = f"{JINA_BASE_URL}{url}"
    headers = {
        "Authorization": f"Bearer {JINA_API_KEY}"
    }
    try:
        async with session.get(full_url, headers=headers) as resp:
            if resp.status == 200:
                return await resp.text()
            else:
                text = await resp.text()
                print(f"Jina fetch error for {url}: {resp.status} - {text}")
                return ""
    except Exception as e:
        print("Error fetching webpage text with Jina:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def process_link(session, link, user_query, search_query):
    """
    Process a single link: fetch its content, judge its usefulness, and if useful, extract the relevant context.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic: Javada string manipulation yapabileceğim metodlar nelerdir
# Enter maximum number of iterations (default 10): 1
#
# === Iteration 1 ===
# Aggregated 30 unique links from this iteration.
# Fetching content from: https://www.w3schools.com/java/java_ref_string.asp
# Fetching content from: https://docs.oracle.com/javase/8/docs/api/java/lang/String.html
# Fetching content from: https://www.geeksforgeeks.org/string-class-in-java/
# Fetching content from: https://docs.oracle.com/en/java/javase/11/docs/api/java.base/java/lang/String.html
# Fetching content from: https://www.programiz.com/java-programming/library/string
# Fetching content from: https://www.w3schools.com/java/java_strings.asp
# Fetching content from: https://www.geeksforgeeks.org/strings-in-java/
# Fetching content from: https://developer.harness.io/docs/platform/variables-and-expressions/expressions-java-methods/
# Fetching content from: https://www.geeksforgeeks.org/java-string-manipulation-best-practices-for-clean-code/
# Fetching content from: https://docs.oracle.com/javase/tutorial/java/data/manipstrings.html
# Fetching content from: https://medium.com/@AlexanderObregon/java-and-string-manipulation-what-beginners-need-to-know-81f971c77539
# Fetching content from: https://dev.to/saurabhkurve/java-string-manipulation-common-methods-you-should-know-li3
# Fetching content from: https://www.jdoodle.com/tutorials/java-module/java-beginner/string-manipulation-in-java
# Fetching content from: https://www.codementor.io/@noelkamphoa/java-string-manipulation-5-key-recipes-for-technical-interviews-part-1-2da6032qaa
# Fetching content from: https://www.guru99.com/string-manipulation-in-java.html
# Fetching content from: https://medium.com/@emrhnozcn/java-string-s%C4%B1n%C4%B1f%C4%B1-69da2b63c246
# Fetching content from: https://umiitkose.com/2015/08/java-string-sinifi-ve-metodlari/
# Fetching content from: https://academy.patika.dev/courses/java101/string-sinifi
# Fetching content from: https://gelecegiyazanlar.turkcell.com.tr/konu/egitim/android-101/javada-string-metodlari
# Fetching content from: https://www.alpaytirasoglu.com/portfolio-item/string-sinifi-ve-metodlari/
# Fetching content from: https://emrecelen.com.tr/javada-string-kullanimi/
# Fetching content from: https://academy.patika.dev/courses/java101/string
# Fetching content from: https://emrecelen.com.tr/javada-diziler/
# Fetching content from: https://kodlamavakti.com/java/string-sinifi-kullanimi/
# Fetching content from: https://codegym.cc/tr/groups/posts/tr.132.javada-alt-dizi
# Fetching content from: https://javaplanet.wordpress.com/2017/03/24/java-string-islemleri/
# Fetching content from: https://www.guru99.com/tr/string-manipulation-in-java.html
# Fetching content from: https://tr.javascript.info/array-methods
# Fetching content from: https://www.youtube.com/watch?v=vBc0qzMTvr0
# Fetching content from: https://medium.com/s%C4%B1f%C4%B1rdan-i%CC%87leri-d%C3%BCzeye-java-e%C4%9Fitim-serisi/array-i%CC%87%C5%9Flemleri-1b3a0efc2640
# Page usefulness for https://developer.harness.io/docs/platform/variables-and-expressions/expressions-java-methods/: Yes
# Page usefulness for https://codegym.cc/tr/groups/posts/tr.132.javada-alt-dizi: Yes
# Page usefulness for https://docs.oracle.com/javase/8/docs/api/java/lang/String.html: Yes
# Page usefulness for https://kodlamavakti.com/java/string-sinifi-kullanimi/: Yes
# Page usefulness for https://docs.oracle.com/javase/tutorial/java/data/manipstrings.html: Yes
# Page usefulness for https://www.w3schools.com/java/java_strings.asp: Yes
# Page usefulness for https://academy.patika.dev/courses/java101/string: Yes
# Page usefulness for https://tr.javascript.info/array-methods: No
# Page usefulness for https://www.alpaytirasoglu.com/portfolio-item/string-sinifi-ve-metodlari/: Yes
# Page usefulness for https://javaplanet.wordpress.com/2017/03/24/java-string-islemleri/: Yes
# Page usefulness for https://www.guru99.com/tr/string-manipulation-in-java.html: Yes
# Page usefulness for https://www.w3schools.com/java/java_ref_string.asp: Yes
# Page usefulness for https://www.geeksforgeeks.org/strings-in-java/: Yes
# Page usefulness for https://emrecelen.com.tr/javada-string-kullanimi/: Yes
# Page usefulness for https://emrecelen.com.tr/javada-diziler/: No
# Page usefulness for https://docs.oracle.com/en/java/javase/11/docs/api/java.base/java/lang/String.html: Yes
# Page usefulness for https://medium.com/@emrhnozcn/java-string-s%C4%B1n%C4%B1f%C4%B1-69da2b63c246: Yes
# Page usefulness for https://medium.com/s%C4%B1f%C4%B1rdan-i%CC%87leri-d%C3%BCzeye-java-e%C4%9Fitim-serisi/array-i%CC%87%C5%9Flemleri-1b3a0efc2640: Yes
# Page usefulness for https://academy.patika.dev/courses/java101/string-sinifi: Yes
# Page usefulness for https://www.programiz.com/java-programming/library/string: Yes
# Page usefulness for https://www.geeksforgeeks.org/java-string-manipulation-best-practices-for-clean-code/: Yes
# Page usefulness for https://medium.com/@AlexanderObregon/java-and-string-manipulation-what-beginners-need-to-know-81f971c77539: Yes
# Page usefulness for https://www.codementor.io/@noelkamphoa/java-string-manipulation-5-key-recipes-for-technical-interviews-part-1-2da6032qaa: Yes
# Page usefulness for https://gelecegiyazanlar.turkcell.com.tr/konu/egitim/android-101/javada-string-metodlari: Yes
# Page usefulness for https://umiitkose.com/2015/08/java-string-sinifi-ve-metodlari/: Yes
# Extracted context from https://docs.oracle.com/javase/8/docs/api/java/lang/String.html (first 200 chars): Java'da string manipulation için kullanabileceğiniz başlıca metodlar şunlardır:
#
# 1. Karşılaştırma Metodları:
# - compareTo()
# - compareToIgnoreCase()
# - equals()
# - equalsIgnoreCase()
#
# 2. Dönüşüm Metodları
# Page usefulness for https://dev.to/saurabhkurve/java-string-manipulation-common-methods-you-should-know-li3: Yes
# Extracted context from https://developer.harness.io/docs/platform/variables-and-expressions/expressions-java-methods/ (first 200 chars): Java'da yaygın olarak kullanılan string metodları şunlardır:
#
# 1. contains(): Bir stringin içinde başka bir stringin olup olmadığını kontrol eder.
#    Örnek: `<+degisken>.contains("aranacak_kelime")`
#
# 2
# Page usefulness for https://www.guru99.com/string-manipulation-in-java.html: Yes
# Extracted context from https://docs.oracle.com/javase/tutorial/java/data/manipstrings.html (first 200 chars): Java'da string manipulation için aşağıdaki metodlar kullanılabilir:
#
# Karakter ve Alt Dizge Alma Metodları:
# - charAt(): Belirli bir indexteki karakteri alır
# - substring(int beginIndex, int endIndex): B
# Extracted context from https://codegym.cc/tr/groups/posts/tr.132.javada-alt-dizi (first 200 chars): Java'da string manipülasyonu için aşağıdaki metodlar kullanılabilir:
#
# 1. substring() metodu:
# - substring(int firstIndex): Belirli bir dizinden itibaren alt dize alma
# - substring(int firstIndex, int la
# Page usefulness for https://www.geeksforgeeks.org/string-class-in-java/: Yes
# Extracted context from https://academy.patika.dev/courses/java101/string (first 200 chars): Here are the key Java string manipulation methods based on the webpage content:
#
# While the webpage doesn't provide a comprehensive list of String methods, it introduces the String class as a part of j
# Extracted context from https://www.alpaytirasoglu.com/portfolio-item/string-sinifi-ve-metodlari/ (first 200 chars): Java'da string manipülasyonu için kullanılabilecek metodlar:
#
# 1. indexOf(): Stringdeki bir karakterin konumunu bulur
# 2. length(): Stringin uzunluğunu verir
# 3. charAt(): Belirli bir konumdaki karakteri
# Extracted context from https://kodlamavakti.com/java/string-sinifi-kullanimi/ (first 200 chars): Java'da string manipülasyonu için kullanabileceğiniz başlıca metodlar şunlardır:
#
# 1. Karakter İşleme Metodları:
# - charAt(): Belirli bir konumdaki karakteri alma
# - toCharArray(): Stringi karakter dizis
# Extracted context from https://emrecelen.com.tr/javada-string-kullanimi/ (first 200 chars): Here are the key Java string manipulation methods from the webpage:
#
# String Manipulation Methods:
# 1. length() - Returns the number of characters in a string
# 2. indexOf("Parameter") - Finds the first o
# Extracted context from https://www.w3schools.com/java/java_strings.asp (first 200 chars): Java'da string manipülasyonu için kullanabileceğiniz başlıca metodlar şunlardır:
#
# 1. length() - String uzunluğunu verir
# 2. toLowerCase() - Stringi küçük harfe çevirir
# 3. toUpperCase() - Stringi büyük
# Extracted context from https://www.guru99.com/tr/string-manipulation-in-java.html (first 200 chars): Java'da dize (string) manipülasyonu için kullanabileceğiniz başlıca metodlar:
#
# 1. Dize Uzunluğu
# - length(): Dizgenin uzunluğunu bulur
#
# 2. Karakter İşlemleri
# - charAt(index): Belirli bir konumdaki ka
# Extracted context from https://www.geeksforgeeks.org/java-string-manipulation-best-practices-for-clean-code/ (first 200 chars): Based on the content, here are the key string manipulation methods in Java:
#
# 1. Concatenation Methods:
# - StringBuilder.append()
# - StringBuffer.append()
#
# 2. Modification Methods:
# - StringBuilder.insert
# Extracted context from https://javaplanet.wordpress.com/2017/03/24/java-string-islemleri/ (first 200 chars): Java'da string manipulation için kullanabileceğiniz metodlar şunlardır:
#
# 1. length(): String'in uzunluğunu döner
# 2. charAt(int index): Belirli bir indeksteki karakteri döner
# 3. substring(): String'in
# Page usefulness for https://www.jdoodle.com/tutorials/java-module/java-beginner/string-manipulation-in-java: No
# Extracted context from https://www.geeksforgeeks.org/strings-in-java/ (first 200 chars): Java'da string manipulation için kullanabileceğiniz başlıca metodlar şunlardır:
#
# 1. length(): String uzunluğunu verir
# 2. charAt(): Belirli bir indexteki karakteri verir
# 3. substring(): String'in belir
# Extracted context from https://www.w3schools.com/java/java_ref_string.asp (first 200 chars): Java'da string manipülasyonu için kullanabileceğiniz başlıca metodlar şunlardır:
#
# 1. length() - String uzunluğunu verir
# 2. charAt() - Belirli bir konumdaki karakteri döndürür
# 3. substring() - Stringin
# Extracted context from https://medium.com/@emrhnozcn/java-string-s%C4%B1n%C4%B1f%C4%B1-69da2b63c246 (first 200 chars): Java'da string üzerinde yapabileceğiniz metodlar şunlardır:
#
# 1. length(): String'in karakter uzunluğunu öğrenme
# 2. equals(): İki string'in içeriğini karşılaştırma
# 3. toUpperCase(): String'i büyük harf
# Extracted context from https://gelecegiyazanlar.turkcell.com.tr/konu/egitim/android-101/javada-string-metodlari (first 200 chars): Java'da String sınıfı ile yapılabilecek metodlar:
#
# 1. length(): String'in karakter sayısını verir
# 2. substring(): String'den belirli bir bölümü çıkarır
# 3. indexOf(): Bir karakterin veya keliminin hang
# Page usefulness for https://www.youtube.com/watch?v=vBc0qzMTvr0: No
# Extracted context from https://www.codementor.io/@noelkamphoa/java-string-manipulation-5-key-recipes-for-technical-interviews-part-1-2da6032qaa (first 200 chars): Java'da string manipülasyonu için aşağıdaki metodlar kullanılabilir:
#
# 1. Whitespace Temizleme Metodları:
# - String.trim(): ASCII karakterlerdeki boşlukları temizler
# - String.strip(): Unicode karakterle
# Extracted context from https://medium.com/s%C4%B1f%C4%B1rdan-i%CC%87leri-d%C3%BCzeye-java-e%C4%9Fitim-serisi/array-i%CC%87%C5%9Flemleri-1b3a0efc2640 (first 200 chars): Java'da string manipülasyonu için kullanılabilecek başlıca metodlar şunlardır:
#
# 1. length(): String uzunluğunu verir
# 2. isEmpty(): String boş mu diye kontrol eder
# 3. charAt(int index): Belirli bir ind
# Extracted context from https://academy.patika.dev/courses/java101/string-sinifi (first 200 chars): Based on the webpage content, here are the Java String manipulation methods:
#
# String Sınıfı Metotları (String Class Methods):
#
# 1. length() - Stringin uzunluğunu verir
# 2. charAt() - Belirli bir konumda
# Extracted context from https://medium.com/@AlexanderObregon/java-and-string-manipulation-what-beginners-need-to-know-81f971c77539 (first 200 chars): Java String Manipulation Metodları:
#
# 1. Concatenation Metodları:
# - `+` operatörü ile birleştirme
# - `concat()` metodu
#
# 2. Karakter İşleme Metodları:
# - `length()`: String uzunluğunu bulma
# - `charAt(int
# Extracted context from https://umiitkose.com/2015/08/java-string-sinifi-ve-metodlari/ (first 200 chars): Burada Java'da kullanabileceğiniz string metodları ve örnekleri listeleniyor:
#
# 1. length(): Stringin karakter sayısını döndürür
#
# 2. indexOf(): Karakterin/alt stringin konumunu bulur
#
# 3. charAt(): Beli
# Extracted context from https://dev.to/saurabhkurve/java-string-manipulation-common-methods-you-should-know-li3 (first 200 chars): Java'da string manipulation için aşağıdaki metodlar kullanılabilir:
#
# 1. Temel Metodlar
# - length(): String uzunluğunu bulma
# - concat(): Stringleri birleştirme
# - equals(): Stringleri karşılaştırma
# - equ
# Extracted context from https://www.programiz.com/java-programming/library/string (first 200 chars): Java'da string manipulation için kullanılabilecek metodlar şunlardır:
#
# 1. split(): Stringi belirtilen regex'e göre böler
# 2. compareTo(): Stringleri sözlük sırasına göre karşılaştırır
# 3. compareToIgnor
# Extracted context from https://www.guru99.com/string-manipulation-in-java.html (first 200 chars): Based on the webpage content, here are the key Java string manipulation methods:
#
# 1. String Concatenation Methods:
# - concat() method
# - "+" operator for joining strings
#
# 2. Length Method:
# - length() -
# Extracted context from https://docs.oracle.com/en/java/javase/11/docs/api/java.base/java/lang/String.html (first 200 chars): Java'da string manipulation için kullanabileceğiniz metodlar şunlardır:
#
# 1. Temel String Metodları:
# - charAt(): Belirli bir indexteki karakteri alma
# - concat(): String birleştirme
# - substring(): Strin
# Extracted context from https://www.geeksforgeeks.org/string-class-in-java/ (first 200 chars): Java'da string manipülasyonu için kullanabileceğiniz başlıca metodlar şunlardır:
#
# 1. length(): String uzunluğunu verir
# 2. charAt(int index): Belirli bir indexteki karakteri döndürür
# 3. substring(int b
# LLM indicated that no further research is needed.
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# Rapor: Java'da String Manipülasyon Metodları
#
# 1. Giriş
# Java'da string manipülasyonu, metinsel verilerin işlenmesi ve dönüştürülmesi için kritik bir yetenektir. String sınıfı, geliştiricilere kapsamlı metin işleme araçları sağlar.
#
# 2. String Manipülasyon Metodları Kategorileri
#
# 2.1 Temel İşlemler
# - length(): String uzunluğunu alma
# - charAt(): Belirli bir indexteki karakteri alma
# - substring(): String'in belirli bir bölümünü çıkarma
#
# 2.2 Karşılaştırma Metodları
# - equals(): İki stringin birebir eşitliğini kontrol etme
# - equalsIgnoreCase(): Büyük/küçük harf duyarsız karşılaştırma
# - compareTo(): Stringleri sözlüksel olarak karşılaştırma
# - contains(): String içinde alt metni arama
#
# 2.3 Dönüşüm Metodları
# - toLowerCase(): Stringi küçük harfe çevirme
# - toUpperCase(): Stringi büyük harfe çevirme
# - trim(): Baş ve sondaki boşlukları silme
# - split(): Stringi parçalara ayırma
#
# 2.4 Değişiklik Metodları
# - replace(): Karakterleri/metinleri değiştirme
# - replaceAll(): Düzenli ifadeyle değişiklik
# - concat(): Stringleri birleştirme
#
# 2.5 Arama Metodları
# - indexOf(): Karakterin/alt metnin ilk konumunu bulma
# - lastIndexOf(): Karakterin/alt metnin son konumunu bulma
# - startsWith(): Stringin belirli bir önek ile başlayıp başlamadığını kontrol etme
# - endsWith(): Stringin belirli bir sonek ile bitip bitmediğini kontrol etme
#
# 3. Performans ve Pratik Öneriler
# - String immutable olduğundan, çok sayıda manipülasyonda StringBuilder kullanın
# - Performanslı string işlemleri için StringBuffer (thread-safe) tercih edilebilir
# - Regex kullanımı karmaşık string manipülasyonlarında faydalıdır
#
# 4. Kod Örnekleri
#
# ```java
# String str = "Hello Java";
# str.length(); // 10
# str.charAt(0); // 'H'
# str.replace("Java", "World"); // "Hello World"
# str.toLowerCase(); // "hello java"
# ```
#
# 5. Sonuç
# Java, zengin string manipülasyon metodları ile geliştiricilere esnek ve güçlü metin işleme imkanı sağlar.
#
# 6. Öneriler
# - Her metodun detaylı dokümantasyonunu inceleme
# - Performans gereksinimlerine göre doğru metodu seçme
# - Düzenli ifade (regex) kullanımını öğrenme
